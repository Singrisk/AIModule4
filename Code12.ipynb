# %% [markdown]
# <h1 align = "center", style = "color:green;">Hierarchical Clustering Programming<h1>

# %% [markdown]
# # Using Scikit-learn

# %%
# Import necessary Libraries. 
import pandas as pd
from sklearn.cluster import AgglomerativeClustering
import matplotlib.pyplot as plt

# %%
# Declare Dataset
data = {
    "x": [1, 2, 3, 8, 9, 10],
    "y": [2, 3, 4, 7, 8, 9]
}

df = pd.DataFrame(data)

# %%
# Defining and Training Model
model = AgglomerativeClustering(n_clusters=2)

df["cluster"] = model.fit_predict(df)

# %%
# Print Dataset
print(df)
# Out:
#     x  y  cluster
# 0   1  2        1
# 1   2  3        1
# 2   3  4        1
# 3   8  7        0
# 4   9  8        0
# 5  10  9        0

# %%
# Calling Model
AgglomerativeClustering(
    n_clusters=2,
    linkage='ward'
)
# Out:
# AgglomerativeClustering()

# %%
# Plotting Clusters
plt.scatter(df["x"], df["y"], c=df["cluster"])
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Hierarchical Clustering")
plt.show()
